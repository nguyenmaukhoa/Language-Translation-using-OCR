# %% [markdown]
# # Language Translation using OCR
#
# You can create many interesting and useful computer vision application once you know how to perform Text Detection and Recognition on images. We will build a simple but useful application that allows you to translate text from one language to a language of your choice. This is particularly useful for tourists going to a country where the local language is very different from their country. Just take a picture of the text you don't understand and the app would tell you what's written!
#
# For the language translation part, we will be using a library called [**googletrans**](https://pypi.org/project/googletrans/) (specifically v4), which uses the Google Translate API under the hood. The **`googletrans`** supports automatic detection of input language and translation to multiple languages.

# %% [markdown]
# ## 1. Prepare

# %%
# Install google translate library
# !pip install googletrans==4.0.0-rc1
# !pip install pyttsx3
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2021.10.8)
# Requirement already satisfied: chardet==3.* in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: sniffio in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.2.0)
# Requirement already satisfied: hstspreload in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2021.12.1)
# Requirement already satisfied: rfc3986<2,>=1.3 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: idna==2.* in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: h2==3.* in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: hpack<4,>=3.0 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: pyttsx3 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (2.90)
# Requirement already satisfied: pyobjc>=2.4 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Contacts==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-EventKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Automator==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AVKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Vision==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Accounts==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Social==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreText==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Speech==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Network==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-GameKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-NetFS==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Security==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreData==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MapKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-OSLog==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AdServices==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-PushKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-PassKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Quartz==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Intents==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Metal==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-Photos==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreML==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-GameController==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-CallKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-core==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-WebKit==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==8.1 in /Users/nguyenkhoa/Docs/OpenCV/beginner/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.1)

# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import googletrans

# %% [markdown]
# ## 2. Google Translator Python API

# %%
# Check language support
print(googletrans.LANGUAGES)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'latin', 'lv': 'latvian', 'lt': 'lithuanian', 'lb': 'luxembourgish', 'mk': 'macedonian', 'mg': 'malagasy', 'ms': 'malay', 'ml': 'malayalam', 'mt': 'maltese', 'mi': 'maori', 'mr': 'marathi', 'mn': 'mongolian', 'my': 'myanmar (burmese)', 'ne': 'nepali', 'no': 'norwegian', 'or': 'odia', 'ps': 'pashto', 'fa': 'persian', 'pl': 'polish', 'pt': 'portuguese', 'pa': 'punjabi', 'ro': 'romanian', 'ru': 'russian', 'sm': 'samoan', 'gd': 'scots gaelic', 'sr': 'serbian', 'st': 'sesotho', 'sn': 'shona', 'sd': 'sindhi', 'si': 'sinhala', 'sk': 'slovak', 'sl': 'slovenian', 'so': 'somali', 'es': 'spanish', 'su': 'sundanese', 'sw': 'swahili', 'sv': 'swedish', 'tg': 'tajik', 'ta': 'tamil', 'te': 'telugu', 'th': 'thai', 'tr': 'turkish', 'uk': 'ukrainian', 'ur': 'urdu', 'ug': 'uyghur', 'uz': 'uzbek', 'vi': 'vietnamese', 'cy': 'welsh', 'xh': 'xhosa', 'yi': 'yiddish', 'yo': 'yoruba', 'zu': 'zulu'}

# %%
# Create translator object
translator = googletrans.Translator()

# %%
# Automatic detection of language
translator.detect('maison').lang
# Out:
# 'fr'

# %%
# Translation example
result = translator.translate('maison', dest='en')
print(result.text)
# Out:
# House

# %%
image = cv2.imread('../visuals/dutch_signboard.jpg')
plt.figure(figsize=(10,8))
plt.imshow(image[:,:,::-1])

# %%
# Define list to store the vocabulary in.
vocabulary =[]

# Open file to import the vocabulary.
with open("./alphabet_94.txt") as f:
    # Read the file line by line, and append each into the vocabulary list.
    for line in f:
        vocabulary.append(line.strip())
    f.close()

# %% [markdown]
# ## 3. Import the text detection and recognition model

# %% [markdown]
# ### <font style="color:rgb(8,133,37)">OpenCV Documentation</font>
#
# For the text detection in the image, we will be using the DB based text detection deep learning neural network model covered in the previous notebook.
#
# [**`DB Text Detection Model()`**](https://docs.opencv.org/master/db/d0f/classcv_1_1dnn_1_1TextDetectionModel__DB.html)

# %%
# DB model for text-detection based on resnet50
textDetector = cv2.dnn_TextDetectionModel_DB('../resources/DB_TD500_resnet50.onnx')
inputSize = (640,640)

# Set threshold for binary map creation and polygon detection
binThresh = 0.3
polyThresh = 0.5

mean = (122.67891434, 116.66876762, 104.00698793)

textDetector.setBinaryThreshold(binThresh).setPolygonThreshold(polyThresh)
textDetector.setInputParams(1.0/255, inputSize, mean, True)

# %% [markdown]
# For the text recognizer we will be using a CRNN based deep learning model that is trained on 2 datasets:
#
# * MJsynth and
# * SynthText
#
# It can identify all characters along with punctuations. Thus, there are 94 characters in the alphabet.
#
# [**`Text Recognition Model()`**](https://docs.opencv.org/4.5.2/de/dee/classcv_1_1dnn_1_1TextRecognitionModel.html)

# %%
# CRNN model for text-recognition
textRecognizer = cv2.dnn_TextRecognitionModel('../resources/crnn_cs.onnx')
textRecognizer.setDecodeType('CTC-greedy')
textRecognizer.setVocabulary(vocabulary)

textRecognizer.setInputParams(1/127.5, (100,32), (127.5, 127.5, 127.5), True)

# %% [markdown]
# ## 4. Align text boxes

# %% [markdown]
# Geometric image transformation functions are used to align the text boxes horizontally by applying perspective transform on the roi boxes detected by the DB text detector. This will help the text recognizer to identify the characters better.
#
# [**`Geometric Image Transforms()`**](https://docs.opencv.org/4.5.2/da/d54/group__imgproc__transform.html)

# %%
def fourPointsTransform(frame, vertices):
    # Print vertices of each bounding box
    vertices = np.asarray(vertices).astype(np.float32)
    outputSize = (100, 32)
    targetVertices = np.array([
        [0, outputSize[1] - 1],
        [0, 0],
        [outputSize[0] - 1, 0],
        [outputSize[0] - 1, outputSize[1] - 1]], dtype='float32')
    
    # Apply perspective transform
    rotationMatrix = cv2.getPerspectiveTransform(vertices, targetVertices)
    result = cv2.warpPerspective(frame, rotationMatrix, outputSize)
    return result

# %% [markdown]
# ## 5. Perform language translation on recognized text

# %%
def recognizeTranslateText(image, dest='en', src='', debug=False):
    # Create a blank matrix to be used to display the output image
    outputCanvas = np.full(image.shape[:3], 255, dtype=np.uint8)
    
    # Use the DB text detector initialized previously to detect the presence of the text in the image
    boxes, confs = textDetector.detect(image)
    
    # Iterate through the bounding boxex detected 
    for box in boxes:
        # Apply transformation 
        croppedRoi = fourPointsTransform(image, box)
        if debug:
            plt.imshow(croppedRoi)
            plt.show()
            
        # Recognize text using the crnn model
        recognizedText = textRecognizer.recognize(croppedRoi)
        print('Recognized Text: ' + recognizedText)
        
        # Perform translate
        translation = translator.translate(recognizedText, dest) 
        print('Translated Text: ' + translation.text + '\n')
        
        # Get scaled values
        boxHeight = int((abs((box[0,1] - box[1,1]))))
        
        # Get scale of the font
        fontScale = cv2.getFontScaleFromHeight(
            cv2.FONT_HERSHEY_SIMPLEX, boxHeight - 5, 1)
        
        # Write the recognized text on the output image
        placement = (int(box[0, 0]), int(box[0, 1]))
        cv2.putText(outputCanvas, translation.text, placement,
            cv2.FONT_HERSHEY_SIMPLEX, fontScale, (255,0,0), 5, 5)
        
    # Draw the bounding boxes of text detected
    cv2.polylines(image, boxes, True, (255, 0, 255), 3)
    
    # Concatenate the input image with the output image
    combineResult = cv2.hconcat([image, outputCanvas])
    
    # Display the output image
    plt.figure(figsize=[20,10])
    plt.imshow(combineResult[:,:,::-1])
    plt.title('Translation Output')

# %% [markdown]
# ## 6. Output Sample

# %%
image = cv2.imread('input_1.png')
recognizeTranslateText(image)
# Out:
# Recognized Text: Peedecaey
# Translated Text: Peedecaey
#
# Recognized Text: utoerHoTisid
# Translated Text: uterhots
#
# Recognized Text: icotoxrminy
# Translated Text: icotoxrminy
#
# Recognized Text: Mlecenteniinind
# Translated Text: Mlecenteniind
#
# Recognized Text: 0notont.mureantne.lc
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/ml/vr5b3d8x05v0y5qr0lc1xgx00000gn/T/ipykernel_29354/3168319182.py in <module>
#       1 image = cv2.imread('input_1.png')
# ----> 2 recognizeTranslateText(image)
#
# /var/folders/ml/vr5b3d8x05v0y5qr0lc1xgx00000gn/T/ipykernel_29354/1891560865.py in recognizeTranslateText(image, dest, src, debug)
#      19
#      20         # Perform translate
# ---> 21         translation = translator.translate(recognizedText, dest)
#      22         print('Translated Text: ' + translation.text + '\n')
#      23
#
# ~/Docs/OpenCV/beginner/lib/python3.9/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     220         # not sure
#     221         should_spacing = parsed[1][0][0][3]
# --> 222         translated_parts = list(map(lambda part: TranslatedPart(part[0], part[1] if len(part) >= 2 else []), parsed[1][0][0][5]))
#     223         translated = (' ' if should_spacing else '').join(map(lambda part: part.text, translated_parts))
#     224
#
# IndexError: list index out of range

# %%
image = cv2.imread('input_2.png')
recognizeTranslateText(image)
# Out:
# Recognized Text: ARRET
# Translated Text: STOP
